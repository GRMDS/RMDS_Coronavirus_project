# %%
import pandas as pd
import requests

# %%
# The purpose of this notebook is as follows :
# 1. Create a function to retrice number of beds at county level
# 
# 2. Create a function to clean collected data
#
# 3. Create a function to combine previous two functions and output data in appopriate format for MongoDB inserting

# %%
### I can only fetch 2000 record at a time from HIFLD's API so I split them into 4 times.
url_0_2000 = 'https://services1.arcgis.com/Hp6G80Pky0om7QvQ/arcgis/rest/services/Hospitals_1/FeatureServer/0/query?where=OBJECTID%20%3E%3D%200%20AND%20OBJECTID%20%3C%3D%202000&outFields=OBJECTID,CITY,STATE,ZIP,COUNTY,COUNTRY,BEDS&returnGeometry=false&outSR=4326&f=json'
url_2001_4000 = 'https://services1.arcgis.com/Hp6G80Pky0om7QvQ/arcgis/rest/services/Hospitals_1/FeatureServer/0/query?where=OBJECTID%20%3E%3D%202001%20AND%20OBJECTID%20%3C%3D%204000&outFields=OBJECTID,CITY,STATE,ZIP,COUNTY,COUNTRY,BEDS&returnGeometry=false&outSR=4326&f=json'
url_4001_6000 = 'https://services1.arcgis.com/Hp6G80Pky0om7QvQ/arcgis/rest/services/Hospitals_1/FeatureServer/0/query?where=OBJECTID%20%3E%3D%204001%20AND%20OBJECTID%20%3C%3D%206000&outFields=OBJECTID,CITY,STATE,ZIP,COUNTY,COUNTRY,BEDS&returnGeometry=false&outSR=4326&f=json'
url_6001_7581 = 'https://services1.arcgis.com/Hp6G80Pky0om7QvQ/arcgis/rest/services/Hospitals_1/FeatureServer/0/query?where=OBJECTID%20%3E%3D%206001%20AND%20OBJECTID%20%3C%3D%208000&outFields=OBJECTID,CITY,STATE,ZIP,COUNTY,COUNTRY,BEDS&returnGeometry=false&outSR=4326&f=json'
url_list = [url_0_2000,url_2001_4000, url_4001_6000, url_6001_7581]

# %%
def retrive_from_API(url):
    '''
    This function takes the url of HIFLD API and reformat it into a dataframe
    Input: URL
    Output: Datafarme
    
    '''
    beds_list = []
    if len(list(url))>=1:
        for i in list(url):
            response = requests.get(url=i)
            list_1 = [i['attributes'] for i in response.json()['features']]
            beds_list += list_1
    else:
        response = requests.get(url)
        beds_list = [i['attributes'] for i in response.json()['features']]
    
    beds_df = pd.DataFrame.from_dict(beds_list)
    return beds_df

# %%
def cleaning(df):
    '''
    Input: dataframe
    - chagne state abbreviation to its full name
    - remove records that do not have county attached
    - fill in missing value with 0
    Output: cleaned dataframe

    '''
    beds_df = df
    beds_df.drop(columns = ['COUNTRY', 'ZIP', 'OBJECTID', 'CITY'], inplace = True)
    beds_df = beds_df[beds_df.COUNTY!='NOT AVAILABLE COUNTY']
    beds_df = beds_df[beds_df.COUNTY!='NOT AVAILABLE']
    us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
    abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))
    beds_df.STATE = [abbrev_us_state[val] for val in beds_df.STATE ]
    beds_df.COUNTY = [val + ' COUNTY' for val in beds_df.COUNTY]
    beds_df.BEDS = [0 if x<0 else x for x in beds_df.BEDS]
    beds_df.columns = ['state_name', 'county_name','num_beds']
    beds_df = beds_df.groupby(['state_name','county_name']).sum().reset_index()
    return beds_df

# %%
def bed_num_county(url):
    '''
    This function takes url of HIFLD API
    Call retrive_from_API and cleaning two functions
    Convert dataframe to list of dictionaries 
    '''
    import pandas as pd
    import requests
    df_1 = retrive_from_API(url_list)
    df_2 = cleaning(df_1)
    beds_dict = df_2.to_dict('record')
    return beds_dict

# %%
bed_num_county(url_list)
# Out:
# [{'state_name': 'Alabama', 'county_name': 'AUTAUGA COUNTY', 'num_beds': 85},
#  {'state_name': 'Alabama', 'county_name': 'BALDWIN COUNTY', 'num_beds': 398},
#  {'state_name': 'Alabama', 'county_name': 'BARBOUR COUNTY', 'num_beds': 74},
#  {'state_name': 'Alabama', 'county_name': 'BIBB COUNTY', 'num_beds': 35},
#  {'state_name': 'Alabama', 'county_name': 'BLOUNT COUNTY', 'num_beds': 40},
#  {'state_name': 'Alabama', 'county_name': 'BULLOCK COUNTY', 'num_beds': 61},
#  {'state_name': 'Alabama', 'county_name': 'BUTLER COUNTY', 'num_beds': 94},
#  {'state_name': 'Alabama', 'county_name': 'CALHOUN COUNTY', 'num_beds': 590},
#  {'state_name': 'Alabama', 'county_name': 'CHAMBERS COUNTY', 'num_beds': 115},
#  {'state_name': 'Alabama', 'county_name': 'CHEROKEE COUNTY', 'num_beds': 60},
#  {'state_name': 'Alabama', 'county_name': 'CHILTON COUNTY', 'num_beds': 26},
#  {'state_name': 'Alabama', 'county_name': 'CHOCTAW COUNTY', 'num_beds': 25},
#  {'state_name': 'Alabama', 'county_name': 'CLARKE COUNTY', 'num_beds': 85},
#  {'state_name': 'Alabama', 'county_name': 'CLAY COUNTY', 'num_beds': 45},
#  {'state_name': 'Alabama', 'county_name': 'COFFEE COUNTY', 'num_beds': 131},
#  {'state_name': 'Alabama', 'county_name': 'COLBERT COUNTY', 'num_beds': 363},
#  {'state_name': 'Alabama', 'county_name': 'CONECUH COUNTY', 'num_beds': 58},
#  {'state_name': 'Alabama', 'county_name': 'COVINGTON COUNTY', 'num_beds': 210},
#  {'state_name': 'Alabama', 'county_name': 'CRENSHAW COUNTY', 'num_beds': 93},
#  {'state_name': 'Alabama', 'county_name': 'CULLMAN COUNTY', 'num_beds': 185},
#  {'state_name': 'Alabama', 'county_name': 'DALE COUNTY', 'num_beds': 89},
#  {'state_name': 'Alabama', 'county_name': 'DALLAS COUNTY', 'num_beds': 175},
#  {'state_name': 'Alabama', 'county_name': 'DEKALB COUNTY', 'num_beds': 134},
#  {'state_name': 'Alabama', 'county_name': 'ELMORE COUNTY', 'num_beds': 138},
#  {'state_name': 'Alabama', 'county_name': 'ESCAMBIA COUNTY', 'num_beds': 142},
#  {'state_name': 'Alabama', 'county_name': 'ETOWAH COUNTY', 'num_beds': 739},
#  {'state_name': 'Alabama', 'county_name': 'FAYETTE COUNTY', 'num_beds': 61},
#  {'state_name': 'Alabama', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 125},
#  {'state_name': 'Alabama', 'county_name': 'GENEVA COUNTY', 'num_beds': 83},
#  {'state_name': 'Alabama', 'county_name': 'GREENE COUNTY', 'num_beds': 20},
#  {'state_name': 'Alabama', 'county_name': 'HALE COUNTY', 'num_beds': 39},
#  {'state_name': 'Alabama', 'county_name': 'HOUSTON COUNTY', 'num_beds': 782},
#  {'state_name': 'Alabama', 'county_name': 'JACKSON COUNTY', 'num_beds': 170},
#  {'state_name': 'Alabama',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 4926},
#  {'state_name': 'Alabama',
#   'county_name': 'LAUDERDALE COUNTY',
#   'num_beds': 358},
#  {'state_name': 'Alabama', 'county_name': 'LAWRENCE COUNTY', 'num_beds': 98},
#  {'state_name': 'Alabama', 'county_name': 'LEE COUNTY', 'num_beds': 314},
#  {'state_name': 'Alabama', 'county_name': 'LIMESTONE COUNTY', 'num_beds': 102},
#  {'state_name': 'Alabama', 'county_name': 'MACON COUNTY', 'num_beds': 0},
#  {'state_name': 'Alabama', 'county_name': 'MADISON COUNTY', 'num_beds': 1178},
#  {'state_name': 'Alabama', 'county_name': 'MARENGO COUNTY', 'num_beds': 99},
#  {'state_name': 'Alabama', 'county_name': 'MARION COUNTY', 'num_beds': 120},
#  {'state_name': 'Alabama', 'county_name': 'MARSHALL COUNTY', 'num_beds': 240},
#  {'state_name': 'Alabama', 'county_name': 'MOBILE COUNTY', 'num_beds': 1929},
#  {'state_name': 'Alabama', 'county_name': 'MONGOMERY COUNTY', 'num_beds': 0},
#  {'state_name': 'Alabama', 'county_name': 'MONROE COUNTY', 'num_beds': 94},
#  {'state_name': 'Alabama',
#   'county_name': 'MONTGOMERY COUNTY',
#   'num_beds': 1143},
#  {'state_name': 'Alabama', 'county_name': 'MORGAN COUNTY', 'num_beds': 476},
#  {'state_name': 'Alabama', 'county_name': 'PICKENS COUNTY', 'num_beds': 56},
#  {'state_name': 'Alabama', 'county_name': 'PIKE COUNTY', 'num_beds': 97},
#  {'state_name': 'Alabama', 'county_name': 'RANDOLPH COUNTY', 'num_beds': 34},
#  {'state_name': 'Alabama', 'county_name': 'RUSSELL COUNTY', 'num_beds': 118},
#  {'state_name': 'Alabama', 'county_name': 'SHELBY COUNTY', 'num_beds': 349},
#  {'state_name': 'Alabama', 'county_name': 'ST. CLAIR COUNTY', 'num_beds': 40},
#  {'state_name': 'Alabama', 'county_name': 'SUMTER COUNTY', 'num_beds': 33},
#  {'state_name': 'Alabama', 'county_name': 'TALLADEGA COUNTY', 'num_beds': 285},
#  {'state_name': 'Alabama',
#   'county_name': 'TALLAPOOSA COUNTY',
#   'num_beds': 127},
#  {'state_name': 'Alabama',
#   'county_name': 'TUSCALOOSA COUNTY',
#   'num_beds': 933},
#  {'state_name': 'Alabama', 'county_name': 'WALKER COUNTY', 'num_beds': 267},
#  {'state_name': 'Alabama', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Alabama', 'county_name': 'WILCOX COUNTY', 'num_beds': 30},
#  {'state_name': 'Alabama', 'county_name': 'WINSTON COUNTY', 'num_beds': 59},
#  {'state_name': 'Alaska',
#   'county_name': 'ALEUTIANS WEST COUNTY',
#   'num_beds': 0},
#  {'state_name': 'Alaska', 'county_name': 'ANCHORAGE COUNTY', 'num_beds': 988},
#  {'state_name': 'Alaska', 'county_name': 'BETHEL COUNTY', 'num_beds': 37},
#  {'state_name': 'Alaska', 'county_name': 'DILLINGHAM COUNTY', 'num_beds': 14},
#  {'state_name': 'Alaska',
#   'county_name': 'FAIRBANKS NORTH STAR COUNTY',
#   'num_beds': 217},
#  {'state_name': 'Alaska', 'county_name': 'JUNEAU COUNTY', 'num_beds': 0},
#  {'state_name': 'Alaska',
#   'county_name': 'KENAI PENINSULA COUNTY',
#   'num_beds': 204},
#  {'state_name': 'Alaska',
#   'county_name': 'KETCHIKAN GATEWAY COUNTY',
#   'num_beds': 54},
#  {'state_name': 'Alaska',
#   'county_name': 'KODIAK ISLAND COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Alaska',
#   'county_name': 'MATANUSKA-SUSITNA COUNTY',
#   'num_beds': 74},
#  {'state_name': 'Alaska', 'county_name': 'NOME COUNTY', 'num_beds': 36},
#  {'state_name': 'Alaska', 'county_name': 'NORTH SLOPE COUNTY', 'num_beds': 0},
#  {'state_name': 'Alaska',
#   'county_name': 'NORTHWEST ARCTIC COUNTY',
#   'num_beds': 17},
#  {'state_name': 'Alaska', 'county_name': 'SITKA COUNTY', 'num_beds': 54},
#  {'state_name': 'Alaska',
#   'county_name': 'VALDEZ-CORDOVA COUNTY',
#   'num_beds': 44},
#  {'state_name': 'Alaska',
#   'county_name': 'WRANGELL-PETERSBURG COUNTY',
#   'num_beds': 49},
#  {'state_name': 'American Samoa',
#   'county_name': 'MAOPUTASI COUNTY',
#   'num_beds': 0},
#  {'state_name': 'Arizona', 'county_name': 'APACHE COUNTY', 'num_beds': 45},
#  {'state_name': 'Arizona', 'county_name': 'COCHISE COUNTY', 'num_beds': 267},
#  {'state_name': 'Arizona', 'county_name': 'COCONINO COUNTY', 'num_beds': 308},
#  {'state_name': 'Arizona', 'county_name': 'GILA COUNTY', 'num_beds': 69},
#  {'state_name': 'Arizona', 'county_name': 'GRAHAM COUNTY', 'num_beds': 49},
#  {'state_name': 'Arizona', 'county_name': 'LA PAZ COUNTY', 'num_beds': 25},
#  {'state_name': 'Arizona', 'county_name': 'MARICOPA COUNTY', 'num_beds': 9767},
#  {'state_name': 'Arizona', 'county_name': 'MOHAVE COUNTY', 'num_beds': 588},
#  {'state_name': 'Arizona', 'county_name': 'NAVAJO COUNTY', 'num_beds': 130},
#  {'state_name': 'Arizona', 'county_name': 'PIMA COUNTY', 'num_beds': 3157},
#  {'state_name': 'Arizona', 'county_name': 'PINAL COUNTY', 'num_beds': 249},
#  {'state_name': 'Arizona', 'county_name': 'SANTA CRUZ COUNTY', 'num_beds': 56},
#  {'state_name': 'Arizona', 'county_name': 'YAVAPAI COUNTY', 'num_beds': 332},
#  {'state_name': 'Arizona', 'county_name': 'YUMA COUNTY', 'num_beds': 410},
#  {'state_name': 'Arkansas', 'county_name': 'ARKANSAS COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'ASHLEY COUNTY', 'num_beds': 33},
#  {'state_name': 'Arkansas', 'county_name': 'BAXTER COUNTY', 'num_beds': 268},
#  {'state_name': 'Arkansas', 'county_name': 'BENTON COUNTY', 'num_beds': 335},
#  {'state_name': 'Arkansas', 'county_name': 'BOONE COUNTY', 'num_beds': 174},
#  {'state_name': 'Arkansas', 'county_name': 'BRADLEY COUNTY', 'num_beds': 35},
#  {'state_name': 'Arkansas', 'county_name': 'CARROLL COUNTY', 'num_beds': 47},
#  {'state_name': 'Arkansas', 'county_name': 'CHICOT COUNTY', 'num_beds': 40},
#  {'state_name': 'Arkansas', 'county_name': 'CLARK COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'CLAY COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'CLEBURNE COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'COLUMBIA COUNTY', 'num_beds': 70},
#  {'state_name': 'Arkansas', 'county_name': 'CONWAY COUNTY', 'num_beds': 35},
#  {'state_name': 'Arkansas',
#   'county_name': 'CRAIGHEAD COUNTY',
#   'num_beds': 631},
#  {'state_name': 'Arkansas', 'county_name': 'CRAWFORD COUNTY', 'num_beds': 103},
#  {'state_name': 'Arkansas',
#   'county_name': 'CRITTENDEN COUNTY',
#   'num_beds': 206},
#  {'state_name': 'Arkansas', 'county_name': 'CROSS COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'DALLAS COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'DESHA COUNTY', 'num_beds': 50},
#  {'state_name': 'Arkansas', 'county_name': 'DREW COUNTY', 'num_beds': 49},
#  {'state_name': 'Arkansas', 'county_name': 'FAULKNER COUNTY', 'num_beds': 172},
#  {'state_name': 'Arkansas', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 0},
#  {'state_name': 'Arkansas', 'county_name': 'FULTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'GARLAND COUNTY', 'num_beds': 646},
#  {'state_name': 'Arkansas', 'county_name': 'GREENE COUNTY', 'num_beds': 129},
#  {'state_name': 'Arkansas', 'county_name': 'HEMPSTEAD COUNTY', 'num_beds': 79},
#  {'state_name': 'Arkansas',
#   'county_name': 'HOT SPRING COUNTY',
#   'num_beds': 100},
#  {'state_name': 'Arkansas', 'county_name': 'HOWARD COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas',
#   'county_name': 'INDEPENDENCE COUNTY',
#   'num_beds': 199},
#  {'state_name': 'Arkansas', 'county_name': 'IZARD COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'JACKSON COUNTY', 'num_beds': 133},
#  {'state_name': 'Arkansas',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 498},
#  {'state_name': 'Arkansas', 'county_name': 'JOHNSON COUNTY', 'num_beds': 80},
#  {'state_name': 'Arkansas', 'county_name': 'LAWRENCE COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas',
#   'county_name': 'LITTLE RIVER COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'LOGAN COUNTY', 'num_beds': 41},
#  {'state_name': 'Arkansas', 'county_name': 'MILLER COUNTY', 'num_beds': 62},
#  {'state_name': 'Arkansas',
#   'county_name': 'MISSISSIPPI COUNTY',
#   'num_beds': 193},
#  {'state_name': 'Arkansas', 'county_name': 'OUACHITA COUNTY', 'num_beds': 100},
#  {'state_name': 'Arkansas', 'county_name': 'PHILLIPS COUNTY', 'num_beds': 155},
#  {'state_name': 'Arkansas', 'county_name': 'PIKE COUNTY', 'num_beds': 32},
#  {'state_name': 'Arkansas', 'county_name': 'POLK COUNTY', 'num_beds': 65},
#  {'state_name': 'Arkansas', 'county_name': 'POPE COUNTY', 'num_beds': 170},
#  {'state_name': 'Arkansas', 'county_name': 'PULASKI COUNTY', 'num_beds': 3323},
#  {'state_name': 'Arkansas', 'county_name': 'RANDOLPH COUNTY', 'num_beds': 50},
#  {'state_name': 'Arkansas', 'county_name': 'SALINE COUNTY', 'num_beds': 244},
#  {'state_name': 'Arkansas', 'county_name': 'SCOTT COUNTY', 'num_beds': 0},
#  {'state_name': 'Arkansas',
#   'county_name': 'SEBASTIAN COUNTY',
#   'num_beds': 1050},
#  {'state_name': 'Arkansas', 'county_name': 'SEVIER COUNTY', 'num_beds': 35},
#  {'state_name': 'Arkansas',
#   'county_name': 'ST. FRANCIS COUNTY',
#   'num_beds': 118},
#  {'state_name': 'Arkansas', 'county_name': 'STONE COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas', 'county_name': 'UNION COUNTY', 'num_beds': 166},
#  {'state_name': 'Arkansas', 'county_name': 'VAN BUREN COUNTY', 'num_beds': 25},
#  {'state_name': 'Arkansas',
#   'county_name': 'WASHINGTON COUNTY',
#   'num_beds': 876},
#  {'state_name': 'Arkansas', 'county_name': 'WHITE COUNTY', 'num_beds': 506},
#  {'state_name': 'Arkansas', 'county_name': 'YELL COUNTY', 'num_beds': 76},
#  {'state_name': 'California',
#   'county_name': 'ALAMEDA COUNTY',
#   'num_beds': 4046},
#  {'state_name': 'California', 'county_name': 'AMADOR COUNTY', 'num_beds': 52},
#  {'state_name': 'California', 'county_name': 'BUTTE COUNTY', 'num_beds': 592},
#  {'state_name': 'California',
#   'county_name': 'CALAVERAS COUNTY',
#   'num_beds': 48},
#  {'state_name': 'California', 'county_name': 'COLUSA COUNTY', 'num_beds': 48},
#  {'state_name': 'California',
#   'county_name': 'CONTRA COSTA COUNTY',
#   'num_beds': 1993},
#  {'state_name': 'California',
#   'county_name': 'DEL NORTE COUNTY',
#   'num_beds': 49},
#  {'state_name': 'California',
#   'county_name': 'EL DORADO COUNTY',
#   'num_beds': 240},
#  {'state_name': 'California',
#   'county_name': 'FRESNO COUNTY',
#   'num_beds': 3551},
#  {'state_name': 'California', 'county_name': 'GLENN COUNTY', 'num_beds': 47},
#  {'state_name': 'California',
#   'county_name': 'HUMBOLDT COUNTY',
#   'num_beds': 299},
#  {'state_name': 'California',
#   'county_name': 'IMPERIAL COUNTY',
#   'num_beds': 268},
#  {'state_name': 'California', 'county_name': 'INYO COUNTY', 'num_beds': 62},
#  {'state_name': 'California', 'county_name': 'KERN COUNTY', 'num_beds': 1833},
#  {'state_name': 'California', 'county_name': 'KINGS COUNTY', 'num_beds': 223},
#  {'state_name': 'California', 'county_name': 'LAKE COUNTY', 'num_beds': 62},
#  {'state_name': 'California', 'county_name': 'LASSEN COUNTY', 'num_beds': 38},
#  {'state_name': 'California',
#   'county_name': 'LOS ANGELES COUNTY',
#   'num_beds': 30371},
#  {'state_name': 'California', 'county_name': 'MADERA COUNTY', 'num_beds': 462},
#  {'state_name': 'California', 'county_name': 'MARIN COUNTY', 'num_beds': 458},
#  {'state_name': 'California',
#   'county_name': 'MARIPOSA COUNTY',
#   'num_beds': 34},
#  {'state_name': 'California',
#   'county_name': 'MENDOCINO COUNTY',
#   'num_beds': 141},
#  {'state_name': 'California', 'county_name': 'MERCED COUNTY', 'num_beds': 246},
#  {'state_name': 'California', 'county_name': 'MODOC COUNTY', 'num_beds': 113},
#  {'state_name': 'California', 'county_name': 'MONO COUNTY', 'num_beds': 17},
#  {'state_name': 'California',
#   'county_name': 'MONTEREY COUNTY',
#   'num_beds': 793},
#  {'state_name': 'California', 'county_name': 'NAPA COUNTY', 'num_beds': 1780},
#  {'state_name': 'California', 'county_name': 'NEVADA COUNTY', 'num_beds': 176},
#  {'state_name': 'California',
#   'county_name': 'ORANGE COUNTY',
#   'num_beds': 8444},
#  {'state_name': 'California', 'county_name': 'PLACER COUNTY', 'num_beds': 748},
#  {'state_name': 'California', 'county_name': 'PLUMAS COUNTY', 'num_beds': 87},
#  {'state_name': 'California',
#   'county_name': 'RIVERSIDE COUNTY',
#   'num_beds': 3945},
#  {'state_name': 'California',
#   'county_name': 'SACRAMENTO COUNTY',
#   'num_beds': 4159},
#  {'state_name': 'California',
#   'county_name': 'SAN BENITO COUNTY',
#   'num_beds': 181},
#  {'state_name': 'California',
#   'county_name': 'SAN BERNARDINO COUNTY',
#   'num_beds': 5929},
#  {'state_name': 'California',
#   'county_name': 'SAN DIEGO COUNTY',
#   'num_beds': 7658},
#  {'state_name': 'California',
#   'county_name': 'SAN FRANCISCO COUNTY',
#   'num_beds': 4828},
#  {'state_name': 'California',
#   'county_name': 'SAN JOAQUIN COUNTY',
#   'num_beds': 1280},
#  {'state_name': 'California',
#   'county_name': 'SAN LUIS OBISPO COUNTY',
#   'num_beds': 1747},
#  {'state_name': 'California',
#   'county_name': 'SAN MATEO COUNTY',
#   'num_beds': 1781},
#  {'state_name': 'California',
#   'county_name': 'SANTA BARBARA COUNTY',
#   'num_beds': 1054},
#  {'state_name': 'California',
#   'county_name': 'SANTA CLARA COUNTY',
#   'num_beds': 3831},
#  {'state_name': 'California',
#   'county_name': 'SANTA CRUZ COUNTY',
#   'num_beds': 432},
#  {'state_name': 'California', 'county_name': 'SHASTA COUNTY', 'num_beds': 763},
#  {'state_name': 'California', 'county_name': 'SIERRA COUNTY', 'num_beds': 39},
#  {'state_name': 'California',
#   'county_name': 'SISKIYOU COUNTY',
#   'num_beds': 61},
#  {'state_name': 'California', 'county_name': 'SOLANO COUNTY', 'num_beds': 749},
#  {'state_name': 'California',
#   'county_name': 'SONOMA COUNTY',
#   'num_beds': 2071},
#  {'state_name': 'California',
#   'county_name': 'STANISLAUS COUNTY',
#   'num_beds': 1729},
#  {'state_name': 'California', 'county_name': 'SUTTER COUNTY', 'num_beds': 92},
#  {'state_name': 'California', 'county_name': 'TEHAMA COUNTY', 'num_beds': 76},
#  {'state_name': 'California', 'county_name': 'TRINITY COUNTY', 'num_beds': 51},
#  {'state_name': 'California',
#   'county_name': 'TULARE COUNTY',
#   'num_beds': 2086},
#  {'state_name': 'California',
#   'county_name': 'TUOLUMNE COUNTY',
#   'num_beds': 152},
#  {'state_name': 'California',
#   'county_name': 'VENTURA COUNTY',
#   'num_beds': 1690},
#  {'state_name': 'California', 'county_name': 'YOLO COUNTY', 'num_beds': 156},
#  {'state_name': 'California', 'county_name': 'YUBA COUNTY', 'num_beds': 173},
#  {'state_name': 'Colorado', 'county_name': 'ADAMS COUNTY', 'num_beds': 716},
#  {'state_name': 'Colorado', 'county_name': 'ALAMOSA COUNTY', 'num_beds': 44},
#  {'state_name': 'Colorado',
#   'county_name': 'ARAPAHOE COUNTY',
#   'num_beds': 1018},
#  {'state_name': 'Colorado', 'county_name': 'ARCHULETA COUNTY', 'num_beds': 11},
#  {'state_name': 'Colorado', 'county_name': 'BACA COUNTY', 'num_beds': 79},
#  {'state_name': 'Colorado', 'county_name': 'BOULDER COUNTY', 'num_beds': 700},
#  {'state_name': 'Colorado',
#   'county_name': 'BROOMFIELD COUNTY',
#   'num_beds': 92},
#  {'state_name': 'Colorado', 'county_name': 'CHAFFEE COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'CHEYENNE COUNTY', 'num_beds': 11},
#  {'state_name': 'Colorado', 'county_name': 'CONEJOS COUNTY', 'num_beds': 17},
#  {'state_name': 'Colorado', 'county_name': 'DELTA COUNTY', 'num_beds': 49},
#  {'state_name': 'Colorado', 'county_name': 'DENVER COUNTY', 'num_beds': 2426},
#  {'state_name': 'Colorado', 'county_name': 'DOUGLAS COUNTY', 'num_beds': 456},
#  {'state_name': 'Colorado', 'county_name': 'EAGLE COUNTY', 'num_beds': 58},
#  {'state_name': 'Colorado', 'county_name': 'EL PASO COUNTY', 'num_beds': 1511},
#  {'state_name': 'Colorado', 'county_name': 'FREMONT COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'GARFIELD COUNTY', 'num_beds': 119},
#  {'state_name': 'Colorado', 'county_name': 'GRAND COUNTY', 'num_beds': 44},
#  {'state_name': 'Colorado', 'county_name': 'GUNNISON COUNTY', 'num_beds': 24},
#  {'state_name': 'Colorado', 'county_name': 'HUERFANO COUNTY', 'num_beds': 20},
#  {'state_name': 'Colorado',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 764},
#  {'state_name': 'Colorado', 'county_name': 'KIOWA COUNTY', 'num_beds': 42},
#  {'state_name': 'Colorado',
#   'county_name': 'KIT CARSON COUNTY',
#   'num_beds': 19},
#  {'state_name': 'Colorado', 'county_name': 'LA PLATA COUNTY', 'num_beds': 94},
#  {'state_name': 'Colorado', 'county_name': 'LAKE COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'LARIMER COUNTY', 'num_beds': 725},
#  {'state_name': 'Colorado',
#   'county_name': 'LAS ANIMAS COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'LINCOLN COUNTY', 'num_beds': 50},
#  {'state_name': 'Colorado', 'county_name': 'LOGAN COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'MESA COUNTY', 'num_beds': 460},
#  {'state_name': 'Colorado', 'county_name': 'MOFFAT COUNTY', 'num_beds': 0},
#  {'state_name': 'Colorado', 'county_name': 'MONTEZUMA COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'MONTROSE COUNTY', 'num_beds': 69},
#  {'state_name': 'Colorado', 'county_name': 'MORGAN COUNTY', 'num_beds': 69},
#  {'state_name': 'Colorado', 'county_name': 'OTERO COUNTY', 'num_beds': 78},
#  {'state_name': 'Colorado', 'county_name': 'PHILLIPS COUNTY', 'num_beds': 40},
#  {'state_name': 'Colorado', 'county_name': 'PITKIN COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'PROWERS COUNTY', 'num_beds': 25},
#  {'state_name': 'Colorado', 'county_name': 'PUEBLO COUNTY', 'num_beds': 1292},
#  {'state_name': 'Colorado',
#   'county_name': 'RIO BLANCO COUNTY',
#   'num_beds': 46},
#  {'state_name': 'Colorado',
#   'county_name': 'RIO GRANDE COUNTY',
#   'num_beds': 17},
#  {'state_name': 'Colorado', 'county_name': 'ROUTT COUNTY', 'num_beds': 98},
#  {'state_name': 'Colorado', 'county_name': 'SEDGWICK COUNTY', 'num_beds': 64},
#  {'state_name': 'Colorado', 'county_name': 'SUMMIT COUNTY', 'num_beds': 34},
#  {'state_name': 'Colorado', 'county_name': 'TELLER COUNTY', 'num_beds': 15},
#  {'state_name': 'Colorado', 'county_name': 'WELD COUNTY', 'num_beds': 300},
#  {'state_name': 'Colorado', 'county_name': 'YUMA COUNTY', 'num_beds': 28},
#  {'state_name': 'Connecticut',
#   'county_name': 'FAIRFIELD COUNTY',
#   'num_beds': 2066},
#  {'state_name': 'Connecticut',
#   'county_name': 'HARTFORD COUNTY',
#   'num_beds': 2980},
#  {'state_name': 'Connecticut',
#   'county_name': 'LITCHFIELD COUNTY',
#   'num_beds': 272},
#  {'state_name': 'Connecticut',
#   'county_name': 'MIDDLESEX COUNTY',
#   'num_beds': 215},
#  {'state_name': 'Connecticut',
#   'county_name': 'NEW HAVEN COUNTY',
#   'num_beds': 3045},
#  {'state_name': 'Connecticut',
#   'county_name': 'NEW LONDON COUNTY',
#   'num_beds': 465},
#  {'state_name': 'Connecticut',
#   'county_name': 'TOLLAND COUNTY',
#   'num_beds': 174},
#  {'state_name': 'Connecticut',
#   'county_name': 'WINDHAM COUNTY',
#   'num_beds': 234},
#  {'state_name': 'Delaware', 'county_name': 'KENT COUNTY', 'num_beds': 288},
#  {'state_name': 'Delaware',
#   'county_name': 'NEW CASTLE COUNTY',
#   'num_beds': 2016},
#  {'state_name': 'Delaware', 'county_name': 'SUSSEX COUNTY', 'num_beds': 476},
#  {'state_name': 'District of Columbia',
#   'county_name': 'DISTRICT OF COLUMBIA COUNTY',
#   'num_beds': 4304},
#  {'state_name': 'Florida', 'county_name': 'ALACHUA COUNTY', 'num_beds': 1765},
#  {'state_name': 'Florida', 'county_name': 'BAKER COUNTY', 'num_beds': 1163},
#  {'state_name': 'Florida', 'county_name': 'BAY COUNTY', 'num_beds': 752},
#  {'state_name': 'Florida', 'county_name': 'BRADFORD COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'BREVARD COUNTY', 'num_beds': 1768},
#  {'state_name': 'Florida', 'county_name': 'BROWARD COUNTY', 'num_beds': 6803},
#  {'state_name': 'Florida', 'county_name': 'CALHOUN COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'CHARLOTTE COUNTY', 'num_beds': 823},
#  {'state_name': 'Florida', 'county_name': 'CITRUS COUNTY', 'num_beds': 332},
#  {'state_name': 'Florida', 'county_name': 'CLAY COUNTY', 'num_beds': 416},
#  {'state_name': 'Florida', 'county_name': 'COLLIER COUNTY', 'num_beds': 1051},
#  {'state_name': 'Florida', 'county_name': 'COLUMBIA COUNTY', 'num_beds': 346},
#  {'state_name': 'Florida', 'county_name': 'DESOTO COUNTY', 'num_beds': 49},
#  {'state_name': 'Florida', 'county_name': 'DUVAL COUNTY', 'num_beds': 4071},
#  {'state_name': 'Florida', 'county_name': 'ESCAMBIA COUNTY', 'num_beds': 1310},
#  {'state_name': 'Florida', 'county_name': 'FLAGLER COUNTY', 'num_beds': 99},
#  {'state_name': 'Florida', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'GADSDEN COUNTY', 'num_beds': 1253},
#  {'state_name': 'Florida', 'county_name': 'GULF COUNTY', 'num_beds': 19},
#  {'state_name': 'Florida', 'county_name': 'HARDEE COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'HENDRY COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'HERNANDO COUNTY', 'num_beds': 620},
#  {'state_name': 'Florida', 'county_name': 'HIGHLANDS COUNTY', 'num_beds': 323},
#  {'state_name': 'Florida',
#   'county_name': 'HILLSBOROUGH COUNTY',
#   'num_beds': 4857},
#  {'state_name': 'Florida', 'county_name': 'HOLMES COUNTY', 'num_beds': 20},
#  {'state_name': 'Florida',
#   'county_name': 'INDIAN RIVER COUNTY',
#   'num_beds': 612},
#  {'state_name': 'Florida', 'county_name': 'JACKSON COUNTY', 'num_beds': 87},
#  {'state_name': 'Florida', 'county_name': 'LAKE COUNTY', 'num_beds': 943},
#  {'state_name': 'Florida', 'county_name': 'LEE COUNTY', 'num_beds': 2240},
#  {'state_name': 'Florida', 'county_name': 'LEON COUNTY', 'num_beds': 1208},
#  {'state_name': 'Florida', 'county_name': 'LEVY COUNTY', 'num_beds': 40},
#  {'state_name': 'Florida', 'county_name': 'MADISON COUNTY', 'num_beds': 25},
#  {'state_name': 'Florida', 'county_name': 'MANATEE COUNTY', 'num_beds': 806},
#  {'state_name': 'Florida', 'county_name': 'MARION COUNTY', 'num_beds': 919},
#  {'state_name': 'Florida', 'county_name': 'MARTIN COUNTY', 'num_beds': 558},
#  {'state_name': 'Florida',
#   'county_name': 'MIAMI-DADE COUNTY',
#   'num_beds': 10243},
#  {'state_name': 'Florida', 'county_name': 'MONROE COUNTY', 'num_beds': 148},
#  {'state_name': 'Florida', 'county_name': 'NASSAU COUNTY', 'num_beds': 54},
#  {'state_name': 'Florida', 'county_name': 'OKALOOSA COUNTY', 'num_beds': 673},
#  {'state_name': 'Florida',
#   'county_name': 'OKEECHOBEE COUNTY',
#   'num_beds': 100},
#  {'state_name': 'Florida', 'county_name': 'ORANGE COUNTY', 'num_beds': 4751},
#  {'state_name': 'Florida', 'county_name': 'OSCEOLA COUNTY', 'num_beds': 997},
#  {'state_name': 'Florida',
#   'county_name': 'PALM BEACH COUNTY',
#   'num_beds': 4993},
#  {'state_name': 'Florida', 'county_name': 'PASCO COUNTY', 'num_beds': 1440},
#  {'state_name': 'Florida', 'county_name': 'PINELLAS COUNTY', 'num_beds': 4229},
#  {'state_name': 'Florida', 'county_name': 'POLK COUNTY', 'num_beds': 1793},
#  {'state_name': 'Florida', 'county_name': 'PUTNAM COUNTY', 'num_beds': 99},
#  {'state_name': 'Florida',
#   'county_name': 'SANTA ROSA COUNTY',
#   'num_beds': 385},
#  {'state_name': 'Florida', 'county_name': 'SARASOTA COUNTY', 'num_beds': 1618},
#  {'state_name': 'Florida', 'county_name': 'SEMINOLE COUNTY', 'num_beds': 965},
#  {'state_name': 'Florida', 'county_name': 'ST. JOHNS COUNTY', 'num_beds': 335},
#  {'state_name': 'Florida', 'county_name': 'ST. LUCIE COUNTY', 'num_beds': 986},
#  {'state_name': 'Florida', 'county_name': 'SUMTER COUNTY', 'num_beds': 339},
#  {'state_name': 'Florida', 'county_name': 'SUWANNEE COUNTY', 'num_beds': 15},
#  {'state_name': 'Florida', 'county_name': 'TAYLOR COUNTY', 'num_beds': 96},
#  {'state_name': 'Florida', 'county_name': 'UNION COUNTY', 'num_beds': 217},
#  {'state_name': 'Florida', 'county_name': 'VOLUSIA COUNTY', 'num_beds': 2042},
#  {'state_name': 'Florida', 'county_name': 'WALTON COUNTY', 'num_beds': 108},
#  {'state_name': 'Florida', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 59},
#  {'state_name': 'Georgia', 'county_name': 'APPLING COUNTY', 'num_beds': 49},
#  {'state_name': 'Georgia', 'county_name': 'BACON COUNTY', 'num_beds': 47},
#  {'state_name': 'Georgia', 'county_name': 'BALDWIN COUNTY', 'num_beds': 340},
#  {'state_name': 'Georgia', 'county_name': 'BARROW COUNTY', 'num_beds': 56},
#  {'state_name': 'Georgia', 'county_name': 'BARTOW COUNTY', 'num_beds': 80},
#  {'state_name': 'Georgia', 'county_name': 'BEN HILL COUNTY', 'num_beds': 75},
#  {'state_name': 'Georgia', 'county_name': 'BERRIEN COUNTY', 'num_beds': 63},
#  {'state_name': 'Georgia', 'county_name': 'BIBB COUNTY', 'num_beds': 1294},
#  {'state_name': 'Georgia', 'county_name': 'BLECKLEY COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'BROOKS COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'BULLOCH COUNTY', 'num_beds': 190},
#  {'state_name': 'Georgia', 'county_name': 'BURKE COUNTY', 'num_beds': 40},
#  {'state_name': 'Georgia', 'county_name': 'BUTTS COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'CALHOUN COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'CAMDEN COUNTY', 'num_beds': 40},
#  {'state_name': 'Georgia', 'county_name': 'CANDLER COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'CARROLL COUNTY', 'num_beds': 344},
#  {'state_name': 'Georgia', 'county_name': 'CATOOSA COUNTY', 'num_beds': 185},
#  {'state_name': 'Georgia', 'county_name': 'CHARLTON COUNTY', 'num_beds': 0},
#  {'state_name': 'Georgia', 'county_name': 'CHATHAM COUNTY', 'num_beds': 1717},
#  {'state_name': 'Georgia',
#   'county_name': 'CHATTAHOOCHEE COUNTY',
#   'num_beds': 57},
#  {'state_name': 'Georgia', 'county_name': 'CHATTOOGA COUNTY', 'num_beds': 31},
#  {'state_name': 'Georgia', 'county_name': 'CHEROKEE COUNTY', 'num_beds': 79},
#  {'state_name': 'Georgia', 'county_name': 'CLARKE COUNTY', 'num_beds': 574},
#  {'state_name': 'Georgia', 'county_name': 'CLAYTON COUNTY', 'num_beds': 558},
#  {'state_name': 'Georgia', 'county_name': 'CLINCH COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'COBB COUNTY', 'num_beds': 1274},
#  {'state_name': 'Georgia', 'county_name': 'COFFEE COUNTY', 'num_beds': 88},
#  {'state_name': 'Georgia', 'county_name': 'COLQUITT COUNTY', 'num_beds': 158},
#  {'state_name': 'Georgia', 'county_name': 'COOK COUNTY', 'num_beds': 60},
#  {'state_name': 'Georgia', 'county_name': 'COWETA COUNTY', 'num_beds': 211},
#  {'state_name': 'Georgia', 'county_name': 'CRISP COUNTY', 'num_beds': 73},
#  {'state_name': 'Georgia', 'county_name': 'DADE COUNTY', 'num_beds': 13},
#  {'state_name': 'Georgia', 'county_name': 'DECATUR COUNTY', 'num_beds': 80},
#  {'state_name': 'Georgia', 'county_name': 'DEKALB COUNTY', 'num_beds': 2604},
#  {'state_name': 'Georgia', 'county_name': 'DODGE COUNTY', 'num_beds': 94},
#  {'state_name': 'Georgia', 'county_name': 'DOOLY COUNTY', 'num_beds': 47},
#  {'state_name': 'Georgia', 'county_name': 'DOUGHERTY COUNTY', 'num_beds': 939},
#  {'state_name': 'Georgia', 'county_name': 'DOUGLAS COUNTY', 'num_beds': 192},
#  {'state_name': 'Georgia', 'county_name': 'EARLY COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'EFFINGHAM COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'ELBERT COUNTY', 'num_beds': 52},
#  {'state_name': 'Georgia', 'county_name': 'EMANUEL COUNTY', 'num_beds': 72},
#  {'state_name': 'Georgia', 'county_name': 'EVANS COUNTY', 'num_beds': 49},
#  {'state_name': 'Georgia', 'county_name': 'FANNIN COUNTY', 'num_beds': 50},
#  {'state_name': 'Georgia', 'county_name': 'FAYETTE COUNTY', 'num_beds': 157},
#  {'state_name': 'Georgia', 'county_name': 'FLOYD COUNTY', 'num_beds': 910},
#  {'state_name': 'Georgia', 'county_name': 'FORSYTH COUNTY', 'num_beds': 187},
#  {'state_name': 'Georgia', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 271},
#  {'state_name': 'Georgia', 'county_name': 'FULTON COUNTY', 'num_beds': 4902},
#  {'state_name': 'Georgia', 'county_name': 'GILMER COUNTY', 'num_beds': 50},
#  {'state_name': 'Georgia', 'county_name': 'GLYNN COUNTY', 'num_beds': 401},
#  {'state_name': 'Georgia', 'county_name': 'GORDON COUNTY', 'num_beds': 80},
#  {'state_name': 'Georgia', 'county_name': 'GRADY COUNTY', 'num_beds': 60},
#  {'state_name': 'Georgia', 'county_name': 'GREENE COUNTY', 'num_beds': 74},
#  {'state_name': 'Georgia', 'county_name': 'GWINNETT COUNTY', 'num_beds': 847},
#  {'state_name': 'Georgia', 'county_name': 'HABERSHAM COUNTY', 'num_beds': 53},
#  {'state_name': 'Georgia', 'county_name': 'HALL COUNTY', 'num_beds': 557},
#  {'state_name': 'Georgia', 'county_name': 'HARALSON COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'HART COUNTY', 'num_beds': 82},
#  {'state_name': 'Georgia', 'county_name': 'HENRY COUNTY', 'num_beds': 265},
#  {'state_name': 'Georgia', 'county_name': 'HOUSTON COUNTY', 'num_beds': 276},
#  {'state_name': 'Georgia', 'county_name': 'IRWIN COUNTY', 'num_beds': 34},
#  {'state_name': 'Georgia', 'county_name': 'JACKSON COUNTY', 'num_beds': 257},
#  {'state_name': 'Georgia', 'county_name': 'JASPER COUNTY', 'num_beds': 17},
#  {'state_name': 'Georgia', 'county_name': 'JEFF DAVIS COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'JEFFERSON COUNTY', 'num_beds': 37},
#  {'state_name': 'Georgia', 'county_name': 'JENKINS COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'LANIER COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'LAURENS COUNTY', 'num_beds': 368},
#  {'state_name': 'Georgia', 'county_name': 'LIBERTY COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'LOWNDES COUNTY', 'num_beds': 475},
#  {'state_name': 'Georgia', 'county_name': 'LUMPKIN COUNTY', 'num_beds': 49},
#  {'state_name': 'Georgia', 'county_name': 'MACON COUNTY', 'num_beds': 49},
#  {'state_name': 'Georgia', 'county_name': 'MCDUFFIE COUNTY', 'num_beds': 72},
#  {'state_name': 'Georgia',
#   'county_name': 'MERIWETHER COUNTY',
#   'num_beds': 188},
#  {'state_name': 'Georgia', 'county_name': 'MILLER COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'MITCHELL COUNTY', 'num_beds': 23},
#  {'state_name': 'Georgia', 'county_name': 'MONROE COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'MORGAN COUNTY', 'num_beds': 41},
#  {'state_name': 'Georgia', 'county_name': 'MURRAY COUNTY', 'num_beds': 42},
#  {'state_name': 'Georgia', 'county_name': 'MUSCOGEE COUNTY', 'num_beds': 1374},
#  {'state_name': 'Georgia', 'county_name': 'NEWTON COUNTY', 'num_beds': 97},
#  {'state_name': 'Georgia', 'county_name': 'PAULDING COUNTY', 'num_beds': 299},
#  {'state_name': 'Georgia', 'county_name': 'PEACH COUNTY', 'num_beds': 50},
#  {'state_name': 'Georgia', 'county_name': 'PICKENS COUNTY', 'num_beds': 48},
#  {'state_name': 'Georgia', 'county_name': 'POLK COUNTY', 'num_beds': 71},
#  {'state_name': 'Georgia', 'county_name': 'PULASKI COUNTY', 'num_beds': 49},
#  {'state_name': 'Georgia', 'county_name': 'PUTNAM COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'RABUN COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'RANDOLPH COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'RICHMOND COUNTY', 'num_beds': 2470},
#  {'state_name': 'Georgia', 'county_name': 'ROCKDALE COUNTY', 'num_beds': 146},
#  {'state_name': 'Georgia', 'county_name': 'SCREVEN COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'SEMINOLE COUNTY', 'num_beds': 65},
#  {'state_name': 'Georgia', 'county_name': 'SPALDING COUNTY', 'num_beds': 160},
#  {'state_name': 'Georgia', 'county_name': 'STEPHENS COUNTY', 'num_beds': 96},
#  {'state_name': 'Georgia', 'county_name': 'STEWART COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'SUMTER COUNTY', 'num_beds': 219},
#  {'state_name': 'Georgia', 'county_name': 'TATTNALL COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'TAYLOR COUNTY', 'num_beds': 0},
#  {'state_name': 'Georgia', 'county_name': 'THOMAS COUNTY', 'num_beds': 664},
#  {'state_name': 'Georgia', 'county_name': 'TIFT COUNTY', 'num_beds': 191},
#  {'state_name': 'Georgia', 'county_name': 'TOOMBS COUNTY', 'num_beds': 57},
#  {'state_name': 'Georgia', 'county_name': 'TOWNS COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'TROUP COUNTY', 'num_beds': 276},
#  {'state_name': 'Georgia', 'county_name': 'UNION COUNTY', 'num_beds': 45},
#  {'state_name': 'Georgia', 'county_name': 'UPSON COUNTY', 'num_beds': 115},
#  {'state_name': 'Georgia', 'county_name': 'WALTON COUNTY', 'num_beds': 192},
#  {'state_name': 'Georgia', 'county_name': 'WARE COUNTY', 'num_beds': 284},
#  {'state_name': 'Georgia',
#   'county_name': 'WASHINGTON COUNTY',
#   'num_beds': 116},
#  {'state_name': 'Georgia', 'county_name': 'WAYNE COUNTY', 'num_beds': 88},
#  {'state_name': 'Georgia', 'county_name': 'WHEELER COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'WHITFIELD COUNTY', 'num_beds': 282},
#  {'state_name': 'Georgia', 'county_name': 'WILKES COUNTY', 'num_beds': 25},
#  {'state_name': 'Georgia', 'county_name': 'WORTH COUNTY', 'num_beds': 25},
#  {'state_name': 'Guam', 'county_name': 'GUAM COUNTY', 'num_beds': 158},
#  {'state_name': 'Hawaii', 'county_name': 'HAWAII COUNTY', 'num_beds': 504},
#  {'state_name': 'Hawaii', 'county_name': 'HONOLULU COUNTY', 'num_beds': 2459},
#  {'state_name': 'Hawaii', 'county_name': 'KAUAI COUNTY', 'num_beds': 144},
#  {'state_name': 'Hawaii', 'county_name': 'MAUI COUNTY', 'num_beds': 258},
#  {'state_name': 'Idaho', 'county_name': 'ADA COUNTY', 'num_beds': 1354},
#  {'state_name': 'Idaho', 'county_name': 'BANNOCK COUNTY', 'num_beds': 219},
#  {'state_name': 'Idaho', 'county_name': 'BEAR LAKE COUNTY', 'num_beds': 21},
#  {'state_name': 'Idaho', 'county_name': 'BENEWAH COUNTY', 'num_beds': 19},
#  {'state_name': 'Idaho', 'county_name': 'BINGHAM COUNTY', 'num_beds': 153},
#  {'state_name': 'Idaho', 'county_name': 'BLAINE COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'BONNER COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'BONNEVILLE COUNTY', 'num_beds': 332},
#  {'state_name': 'Idaho', 'county_name': 'BOUNDARY COUNTY', 'num_beds': 20},
#  {'state_name': 'Idaho', 'county_name': 'BUTTE COUNTY', 'num_beds': 14},
#  {'state_name': 'Idaho', 'county_name': 'CANYON COUNTY', 'num_beds': 302},
#  {'state_name': 'Idaho', 'county_name': 'CARIBOU COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'CASSIA COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'CLEARWATER COUNTY', 'num_beds': 83},
#  {'state_name': 'Idaho', 'county_name': 'ELMORE COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 20},
#  {'state_name': 'Idaho', 'county_name': 'GEM COUNTY', 'num_beds': 16},
#  {'state_name': 'Idaho', 'county_name': 'GOODING COUNTY', 'num_beds': 18},
#  {'state_name': 'Idaho', 'county_name': 'IDAHO COUNTY', 'num_beds': 41},
#  {'state_name': 'Idaho', 'county_name': 'JEROME COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'KOOTENAI COUNTY', 'num_beds': 396},
#  {'state_name': 'Idaho', 'county_name': 'LATAH COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'LEMHI COUNTY', 'num_beds': 18},
#  {'state_name': 'Idaho', 'county_name': 'MADISON COUNTY', 'num_beds': 69},
#  {'state_name': 'Idaho', 'county_name': 'MINIDOKA COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'NEZ PERCE COUNTY', 'num_beds': 145},
#  {'state_name': 'Idaho', 'county_name': 'ONEIDA COUNTY', 'num_beds': 11},
#  {'state_name': 'Idaho', 'county_name': 'POWER COUNTY', 'num_beds': 10},
#  {'state_name': 'Idaho', 'county_name': 'SHOSHONE COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'TETON COUNTY', 'num_beds': 13},
#  {'state_name': 'Idaho', 'county_name': 'TWIN FALLS COUNTY', 'num_beds': 253},
#  {'state_name': 'Idaho', 'county_name': 'VALLEY COUNTY', 'num_beds': 25},
#  {'state_name': 'Idaho', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'ADAMS COUNTY', 'num_beds': 335},
#  {'state_name': 'Illinois', 'county_name': 'BOND COUNTY', 'num_beds': 150},
#  {'state_name': 'Illinois', 'county_name': 'BOONE COUNTY', 'num_beds': 0},
#  {'state_name': 'Illinois', 'county_name': 'BUREAU COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois',
#   'county_name': 'CHAMPAIGN COUNTY',
#   'num_beds': 549},
#  {'state_name': 'Illinois', 'county_name': 'CHRISTIAN COUNTY', 'num_beds': 67},
#  {'state_name': 'Illinois', 'county_name': 'CLAY COUNTY', 'num_beds': 18},
#  {'state_name': 'Illinois', 'county_name': 'CLINTON COUNTY', 'num_beds': 0},
#  {'state_name': 'Illinois', 'county_name': 'COLES COUNTY', 'num_beds': 118},
#  {'state_name': 'Illinois', 'county_name': 'COOK COUNTY', 'num_beds': 18259},
#  {'state_name': 'Illinois', 'county_name': 'CRAWFORD COUNTY', 'num_beds': 63},
#  {'state_name': 'Illinois', 'county_name': 'DE WITT COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'DEKALB COUNTY', 'num_beds': 191},
#  {'state_name': 'Illinois', 'county_name': 'DUPAGE COUNTY', 'num_beds': 1880},
#  {'state_name': 'Illinois', 'county_name': 'EDGAR COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois',
#   'county_name': 'EFFINGHAM COUNTY',
#   'num_beds': 146},
#  {'state_name': 'Illinois', 'county_name': 'FAYETTE COUNTY', 'num_beds': 110},
#  {'state_name': 'Illinois', 'county_name': 'FORD COUNTY', 'num_beds': 67},
#  {'state_name': 'Illinois', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'FULTON COUNTY', 'num_beds': 93},
#  {'state_name': 'Illinois', 'county_name': 'GREENE COUNTY', 'num_beds': 286},
#  {'state_name': 'Illinois', 'county_name': 'GRUNDY COUNTY', 'num_beds': 89},
#  {'state_name': 'Illinois', 'county_name': 'HAMILTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'HANCOCK COUNTY', 'num_beds': 18},
#  {'state_name': 'Illinois', 'county_name': 'HARDIN COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'HENRY COUNTY', 'num_beds': 86},
#  {'state_name': 'Illinois', 'county_name': 'IROQUOIS COUNTY', 'num_beds': 84},
#  {'state_name': 'Illinois', 'county_name': 'JACKSON COUNTY', 'num_beds': 184},
#  {'state_name': 'Illinois',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 187},
#  {'state_name': 'Illinois', 'county_name': 'JERSEY COUNTY', 'num_beds': 49},
#  {'state_name': 'Illinois',
#   'county_name': 'JO DAVIESS COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'KANE COUNTY', 'num_beds': 1101},
#  {'state_name': 'Illinois', 'county_name': 'KANKAKEE COUNTY', 'num_beds': 468},
#  {'state_name': 'Illinois', 'county_name': 'KNOX COUNTY', 'num_beds': 209},
#  {'state_name': 'Illinois', 'county_name': 'LA SALLE COUNTY', 'num_beds': 269},
#  {'state_name': 'Illinois', 'county_name': 'LAKE COUNTY', 'num_beds': 968},
#  {'state_name': 'Illinois', 'county_name': 'LAWRENCE COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'LEE COUNTY', 'num_beds': 80},
#  {'state_name': 'Illinois',
#   'county_name': 'LIVINGSTON COUNTY',
#   'num_beds': 42},
#  {'state_name': 'Illinois', 'county_name': 'LOGAN COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'MACON COUNTY', 'num_beds': 188},
#  {'state_name': 'Illinois', 'county_name': 'MACOUPIN COUNTY', 'num_beds': 50},
#  {'state_name': 'Illinois', 'county_name': 'MADISON COUNTY', 'num_beds': 968},
#  {'state_name': 'Illinois', 'county_name': 'MARION COUNTY', 'num_beds': 135},
#  {'state_name': 'Illinois', 'county_name': 'MASON COUNTY', 'num_beds': 20},
#  {'state_name': 'Illinois', 'county_name': 'MASSAC COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'MCDONOUGH COUNTY', 'num_beds': 95},
#  {'state_name': 'Illinois', 'county_name': 'MCHENRY COUNTY', 'num_beds': 343},
#  {'state_name': 'Illinois', 'county_name': 'MCLEAN COUNTY', 'num_beds': 200},
#  {'state_name': 'Illinois', 'county_name': 'MERCER COUNTY', 'num_beds': 22},
#  {'state_name': 'Illinois',
#   'county_name': 'MONTGOMERY COUNTY',
#   'num_beds': 50},
#  {'state_name': 'Illinois', 'county_name': 'MORGAN COUNTY', 'num_beds': 108},
#  {'state_name': 'Illinois', 'county_name': 'OGLE COUNTY', 'num_beds': 16},
#  {'state_name': 'Illinois', 'county_name': 'PEORIA COUNTY', 'num_beds': 1122},
#  {'state_name': 'Illinois', 'county_name': 'PERRY COUNTY', 'num_beds': 50},
#  {'state_name': 'Illinois', 'county_name': 'PIATT COUNTY', 'num_beds': 16},
#  {'state_name': 'Illinois', 'county_name': 'PIKE COUNTY', 'num_beds': 21},
#  {'state_name': 'Illinois', 'county_name': 'RANDOLPH COUNTY', 'num_beds': 165},
#  {'state_name': 'Illinois', 'county_name': 'RICHLAND COUNTY', 'num_beds': 90},
#  {'state_name': 'Illinois',
#   'county_name': 'ROCK ISLAND COUNTY',
#   'num_beds': 444},
#  {'state_name': 'Illinois', 'county_name': 'SALINE COUNTY', 'num_beds': 98},
#  {'state_name': 'Illinois',
#   'county_name': 'SANGAMON COUNTY',
#   'num_beds': 1045},
#  {'state_name': 'Illinois', 'county_name': 'SCHUYLER COUNTY', 'num_beds': 46},
#  {'state_name': 'Illinois', 'county_name': 'SHELBY COUNTY', 'num_beds': 30},
#  {'state_name': 'Illinois',
#   'county_name': 'ST. CLAIR COUNTY',
#   'num_beds': 818},
#  {'state_name': 'Illinois',
#   'county_name': 'STEPHENSON COUNTY',
#   'num_beds': 100},
#  {'state_name': 'Illinois', 'county_name': 'TAZEWELL COUNTY', 'num_beds': 150},
#  {'state_name': 'Illinois', 'county_name': 'UNION COUNTY', 'num_beds': 47},
#  {'state_name': 'Illinois',
#   'county_name': 'VERMILION COUNTY',
#   'num_beds': 447},
#  {'state_name': 'Illinois', 'county_name': 'WABASH COUNTY', 'num_beds': 25},
#  {'state_name': 'Illinois', 'county_name': 'WARREN COUNTY', 'num_beds': 23},
#  {'state_name': 'Illinois', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 0},
#  {'state_name': 'Illinois', 'county_name': 'WAYNE COUNTY', 'num_beds': 55},
#  {'state_name': 'Illinois',
#   'county_name': 'WHITESIDE COUNTY',
#   'num_beds': 135},
#  {'state_name': 'Illinois', 'county_name': 'WILL COUNTY', 'num_beds': 917},
#  {'state_name': 'Illinois',
#   'county_name': 'WILLIAMSON COUNTY',
#   'num_beds': 431},
#  {'state_name': 'Illinois',
#   'county_name': 'WINNEBAGO COUNTY',
#   'num_beds': 907},
#  {'state_name': 'Illinois', 'county_name': 'WOODFORD COUNTY', 'num_beds': 18},
#  {'state_name': 'Indiana', 'county_name': 'ADAMS COUNTY', 'num_beds': 35},
#  {'state_name': 'Indiana', 'county_name': 'ALLEN COUNTY', 'num_beds': 1558},
#  {'state_name': 'Indiana',
#   'county_name': 'BARTHOLOMEW COUNTY',
#   'num_beds': 198},
#  {'state_name': 'Indiana', 'county_name': 'BLACKFORD COUNTY', 'num_beds': 15},
#  {'state_name': 'Indiana', 'county_name': 'BOONE COUNTY', 'num_beds': 52},
#  {'state_name': 'Indiana', 'county_name': 'CASS COUNTY', 'num_beds': 98},
#  {'state_name': 'Indiana', 'county_name': 'CLARK COUNTY', 'num_beds': 442},
#  {'state_name': 'Indiana', 'county_name': 'CLAY COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'CLINTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'DAVIESS COUNTY', 'num_beds': 80},
#  {'state_name': 'Indiana', 'county_name': 'DEARBORN COUNTY', 'num_beds': 104},
#  {'state_name': 'Indiana', 'county_name': 'DECATUR COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'DEKALB COUNTY', 'num_beds': 72},
#  {'state_name': 'Indiana', 'county_name': 'DELAWARE COUNTY', 'num_beds': 411},
#  {'state_name': 'Indiana', 'county_name': 'DUBOIS COUNTY', 'num_beds': 123},
#  {'state_name': 'Indiana', 'county_name': 'ELKHART COUNTY', 'num_beds': 406},
#  {'state_name': 'Indiana', 'county_name': 'FAYETTE COUNTY', 'num_beds': 99},
#  {'state_name': 'Indiana', 'county_name': 'FLOYD COUNTY', 'num_beds': 297},
#  {'state_name': 'Indiana', 'county_name': 'FULTON COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'GIBSON COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'GRANT COUNTY', 'num_beds': 113},
#  {'state_name': 'Indiana', 'county_name': 'GREENE COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'HAMILTON COUNTY', 'num_beds': 577},
#  {'state_name': 'Indiana', 'county_name': 'HANCOCK COUNTY', 'num_beds': 68},
#  {'state_name': 'Indiana', 'county_name': 'HARRISON COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'HENDRICKS COUNTY', 'num_beds': 287},
#  {'state_name': 'Indiana', 'county_name': 'HENRY COUNTY', 'num_beds': 90},
#  {'state_name': 'Indiana', 'county_name': 'HOWARD COUNTY', 'num_beds': 254},
#  {'state_name': 'Indiana', 'county_name': 'HUNTINGTON COUNTY', 'num_beds': 36},
#  {'state_name': 'Indiana', 'county_name': 'JACKSON COUNTY', 'num_beds': 93},
#  {'state_name': 'Indiana', 'county_name': 'JASPER COUNTY', 'num_beds': 46},
#  {'state_name': 'Indiana', 'county_name': 'JAY COUNTY', 'num_beds': 35},
#  {'state_name': 'Indiana', 'county_name': 'JEFFERSON COUNTY', 'num_beds': 299},
#  {'state_name': 'Indiana', 'county_name': 'JENNINGS COUNTY', 'num_beds': 17},
#  {'state_name': 'Indiana', 'county_name': 'JOHNSON COUNTY', 'num_beds': 275},
#  {'state_name': 'Indiana', 'county_name': 'KNOX COUNTY', 'num_beds': 175},
#  {'state_name': 'Indiana', 'county_name': 'KOSCIUSKO COUNTY', 'num_beds': 88},
#  {'state_name': 'Indiana', 'county_name': 'LAGRANGE COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'LAKE COUNTY', 'num_beds': 2605},
#  {'state_name': 'Indiana', 'county_name': 'LAPORTE COUNTY', 'num_beds': 377},
#  {'state_name': 'Indiana', 'county_name': 'LAWRENCE COUNTY', 'num_beds': 50},
#  {'state_name': 'Indiana', 'county_name': 'MADISON COUNTY', 'num_beds': 402},
#  {'state_name': 'Indiana', 'county_name': 'MARION COUNTY', 'num_beds': 3640},
#  {'state_name': 'Indiana', 'county_name': 'MARSHALL COUNTY', 'num_beds': 160},
#  {'state_name': 'Indiana', 'county_name': 'MIAMI COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'MONROE COUNTY', 'num_beds': 368},
#  {'state_name': 'Indiana',
#   'county_name': 'MONTGOMERY COUNTY',
#   'num_beds': 103},
#  {'state_name': 'Indiana', 'county_name': 'MORGAN COUNTY', 'num_beds': 207},
#  {'state_name': 'Indiana', 'county_name': 'NOBLE COUNTY', 'num_beds': 31},
#  {'state_name': 'Indiana', 'county_name': 'ORANGE COUNTY', 'num_beds': 24},
#  {'state_name': 'Indiana', 'county_name': 'PERRY COUNTY', 'num_beds': 25},
#  {'state_name': 'Indiana', 'county_name': 'PORTER COUNTY', 'num_beds': 317},
#  {'state_name': 'Indiana', 'county_name': 'PULASKI COUNTY', 'num_beds': 25},
# ...
#  {'state_name': 'Kansas', 'county_name': 'RUSSELL COUNTY', 'num_beds': 46},
#  {'state_name': 'Kansas', 'county_name': 'SALINE COUNTY', 'num_beds': 214},
#  {'state_name': 'Kansas', 'county_name': 'SCOTT COUNTY', 'num_beds': 50},
#  {'state_name': 'Kansas', 'county_name': 'SEDGWICK COUNTY', 'num_beds': 1140},
#  {'state_name': 'Kansas', 'county_name': 'SEWARD COUNTY', 'num_beds': 101},
#  {'state_name': 'Kansas', 'county_name': 'SHAWNEE COUNTY', 'num_beds': 768},
#  {'state_name': 'Kansas', 'county_name': 'SHERIDAN COUNTY', 'num_beds': 53},
#  {'state_name': 'Kansas', 'county_name': 'SHERMAN COUNTY', 'num_beds': 25},
#  {'state_name': 'Kansas', 'county_name': 'SMITH COUNTY', 'num_beds': 53},
#  {'state_name': 'Kansas', 'county_name': 'STAFFORD COUNTY', 'num_beds': 25},
#  {'state_name': 'Kansas', 'county_name': 'STANTON COUNTY', 'num_beds': 34},
#  {'state_name': 'Kansas', 'county_name': 'STEVENS COUNTY', 'num_beds': 100},
#  {'state_name': 'Kansas', 'county_name': 'SUMNER COUNTY', 'num_beds': 76},
#  {'state_name': 'Kansas', 'county_name': 'THOMAS COUNTY', 'num_beds': 88},
#  {'state_name': 'Kansas', 'county_name': 'TREGO COUNTY', 'num_beds': 62},
#  {'state_name': 'Kansas', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 50},
#  {'state_name': 'Kansas', 'county_name': 'WICHITA COUNTY', 'num_beds': 37},
#  {'state_name': 'Kansas', 'county_name': 'WILSON COUNTY', 'num_beds': 49},
#  {'state_name': 'Kansas', 'county_name': 'WYANDOTTE COUNTY', 'num_beds': 1232},
#  {'state_name': 'Kentucky', 'county_name': 'ADAIR COUNTY', 'num_beds': 77},
#  {'state_name': 'Kentucky', 'county_name': 'ALLEN COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'BARREN COUNTY', 'num_beds': 180},
#  {'state_name': 'Kentucky', 'county_name': 'BELL COUNTY', 'num_beds': 216},
#  {'state_name': 'Kentucky', 'county_name': 'BOONE COUNTY', 'num_beds': 201},
#  {'state_name': 'Kentucky', 'county_name': 'BOURBON COUNTY', 'num_beds': 58},
#  {'state_name': 'Kentucky', 'county_name': 'BOYD COUNTY', 'num_beds': 455},
#  {'state_name': 'Kentucky', 'county_name': 'BOYLE COUNTY', 'num_beds': 222},
#  {'state_name': 'Kentucky', 'county_name': 'BREATHITT COUNTY', 'num_beds': 55},
#  {'state_name': 'Kentucky',
#   'county_name': 'BRECKINRIDGE COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'CALDWELL COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'CALLOWAY COUNTY', 'num_beds': 152},
#  {'state_name': 'Kentucky', 'county_name': 'CAMPBELL COUNTY', 'num_beds': 284},
#  {'state_name': 'Kentucky', 'county_name': 'CARROLL COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'CASEY COUNTY', 'num_beds': 15},
#  {'state_name': 'Kentucky',
#   'county_name': 'CHRISTIAN COUNTY',
#   'num_beds': 786},
#  {'state_name': 'Kentucky', 'county_name': 'CLARK COUNTY', 'num_beds': 54},
#  {'state_name': 'Kentucky', 'county_name': 'CLAY COUNTY', 'num_beds': 63},
#  {'state_name': 'Kentucky', 'county_name': 'CLINTON COUNTY', 'num_beds': 42},
#  {'state_name': 'Kentucky',
#   'county_name': 'CRITTENDEN COUNTY',
#   'num_beds': 48},
#  {'state_name': 'Kentucky',
#   'county_name': 'CUMBERLAND COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'DAVIESS COUNTY', 'num_beds': 527},
#  {'state_name': 'Kentucky', 'county_name': 'ESTILL COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'FAYETTE COUNTY', 'num_beds': 2379},
#  {'state_name': 'Kentucky', 'county_name': 'FLEMING COUNTY', 'num_beds': 52},
#  {'state_name': 'Kentucky', 'county_name': 'FLOYD COUNTY', 'num_beds': 251},
#  {'state_name': 'Kentucky', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 173},
#  {'state_name': 'Kentucky', 'county_name': 'FULTON COUNTY', 'num_beds': 70},
#  {'state_name': 'Kentucky', 'county_name': 'GARRARD COUNTY', 'num_beds': 15},
#  {'state_name': 'Kentucky', 'county_name': 'GRANT COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'GRAVES COUNTY', 'num_beds': 107},
#  {'state_name': 'Kentucky', 'county_name': 'GRAYSON COUNTY', 'num_beds': 75},
#  {'state_name': 'Kentucky', 'county_name': 'GREEN COUNTY', 'num_beds': 35},
#  {'state_name': 'Kentucky', 'county_name': 'GREENUP COUNTY', 'num_beds': 190},
#  {'state_name': 'Kentucky', 'county_name': 'HARDIN COUNTY', 'num_beds': 465},
#  {'state_name': 'Kentucky', 'county_name': 'HARLAN COUNTY', 'num_beds': 150},
#  {'state_name': 'Kentucky', 'county_name': 'HARRISON COUNTY', 'num_beds': 61},
#  {'state_name': 'Kentucky', 'county_name': 'HART COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky',
#   'county_name': 'HENDERSON COUNTY',
#   'num_beds': 192},
#  {'state_name': 'Kentucky', 'county_name': 'HOPKINS COUNTY', 'num_beds': 390},
#  {'state_name': 'Kentucky',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 4795},
#  {'state_name': 'Kentucky', 'county_name': 'JOHNSON COUNTY', 'num_beds': 72},
#  {'state_name': 'Kentucky', 'county_name': 'KENTON COUNTY', 'num_beds': 728},
#  {'state_name': 'Kentucky', 'county_name': 'KNOX COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'LAUREL COUNTY', 'num_beds': 150},
#  {'state_name': 'Kentucky', 'county_name': 'LAWRENCE COUNTY', 'num_beds': 90},
#  {'state_name': 'Kentucky', 'county_name': 'LESLIE COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'LETCHER COUNTY', 'num_beds': 90},
#  {'state_name': 'Kentucky', 'county_name': 'LINCOLN COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky',
#   'county_name': 'LIVINGSTON COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'LOGAN COUNTY', 'num_beds': 75},
#  {'state_name': 'Kentucky', 'county_name': 'MADISON COUNTY', 'num_beds': 130},
#  {'state_name': 'Kentucky', 'county_name': 'MARION COUNTY', 'num_beds': 75},
#  {'state_name': 'Kentucky', 'county_name': 'MARSHALL COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'MASON COUNTY', 'num_beds': 100},
#  {'state_name': 'Kentucky',
#   'county_name': 'MCCRACKEN COUNTY',
#   'num_beds': 708},
#  {'state_name': 'Kentucky', 'county_name': 'MERCER COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'MONROE COUNTY', 'num_beds': 49},
#  {'state_name': 'Kentucky',
#   'county_name': 'MONTGOMERY COUNTY',
#   'num_beds': 42},
#  {'state_name': 'Kentucky', 'county_name': 'MORGAN COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky',
#   'county_name': 'MUHLENBERG COUNTY',
#   'num_beds': 90},
#  {'state_name': 'Kentucky', 'county_name': 'NELSON COUNTY', 'num_beds': 40},
#  {'state_name': 'Kentucky', 'county_name': 'NICHOLAS COUNTY', 'num_beds': 18},
#  {'state_name': 'Kentucky', 'county_name': 'OHIO COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'OLDHAM COUNTY', 'num_beds': 187},
#  {'state_name': 'Kentucky', 'county_name': 'OWEN COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'PERRY COUNTY', 'num_beds': 358},
#  {'state_name': 'Kentucky', 'county_name': 'PIKE COUNTY', 'num_beds': 374},
#  {'state_name': 'Kentucky', 'county_name': 'PULASKI COUNTY', 'num_beds': 295},
#  {'state_name': 'Kentucky',
#   'county_name': 'ROCKCASTLE COUNTY',
#   'num_beds': 26},
#  {'state_name': 'Kentucky', 'county_name': 'ROWAN COUNTY', 'num_beds': 149},
#  {'state_name': 'Kentucky', 'county_name': 'RUSSELL COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'SCOTT COUNTY', 'num_beds': 75},
#  {'state_name': 'Kentucky', 'county_name': 'SHELBY COUNTY', 'num_beds': 70},
#  {'state_name': 'Kentucky', 'county_name': 'SIMPSON COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'TAYLOR COUNTY', 'num_beds': 90},
#  {'state_name': 'Kentucky', 'county_name': 'TRIGG COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'UNION COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'WARREN COUNTY', 'num_beds': 733},
#  {'state_name': 'Kentucky', 'county_name': 'WAYNE COUNTY', 'num_beds': 25},
#  {'state_name': 'Kentucky', 'county_name': 'WHITLEY COUNTY', 'num_beds': 273},
#  {'state_name': 'Kentucky', 'county_name': 'WOODFORD COUNTY', 'num_beds': 25},
#  {'state_name': 'Louisiana', 'county_name': 'ACADIA COUNTY', 'num_beds': 59},
#  {'state_name': 'Louisiana', 'county_name': 'ALLEN COUNTY', 'num_beds': 76},
#  {'state_name': 'Louisiana',
#   'county_name': 'ASCENSION COUNTY',
#   'num_beds': 125},
#  {'state_name': 'Louisiana',
#   'county_name': 'ASSUMPTION COUNTY',
#   'num_beds': 6},
#  {'state_name': 'Louisiana',
#   'county_name': 'AVOYELLES COUNTY',
#   'num_beds': 55},
#  {'state_name': 'Louisiana',
#   'county_name': 'BEAUREGARD COUNTY',
#   'num_beds': 80},
#  {'state_name': 'Louisiana',
#   'county_name': 'BIENVILLE COUNTY',
#   'num_beds': 21},
#  {'state_name': 'Louisiana', 'county_name': 'BOSSIER COUNTY', 'num_beds': 404},
#  {'state_name': 'Louisiana', 'county_name': 'CADDO COUNTY', 'num_beds': 2328},
#  {'state_name': 'Louisiana',
#   'county_name': 'CALCASIEU COUNTY',
#   'num_beds': 788},
#  {'state_name': 'Louisiana', 'county_name': 'CALDWELL COUNTY', 'num_beds': 65},
#  {'state_name': 'Louisiana', 'county_name': 'CAMERON COUNTY', 'num_beds': 49},
#  {'state_name': 'Louisiana', 'county_name': 'CLAIBORNE COUNTY', 'num_beds': 0},
#  {'state_name': 'Louisiana',
#   'county_name': 'CONCORDIA COUNTY',
#   'num_beds': 65},
#  {'state_name': 'Louisiana', 'county_name': 'DE SOTO COUNTY', 'num_beds': 0},
#  {'state_name': 'Louisiana',
#   'county_name': 'EAST BATON ROUGE COUNTY',
#   'num_beds': 2733},
#  {'state_name': 'Louisiana',
#   'county_name': 'EAST CARROLL COUNTY',
#   'num_beds': 11},
#  {'state_name': 'Louisiana',
#   'county_name': 'EAST FELICIANA COUNTY',
#   'num_beds': 506},
#  {'state_name': 'Louisiana',
#   'county_name': 'EVANGELINE COUNTY',
#   'num_beds': 250},
#  {'state_name': 'Louisiana', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 43},
#  {'state_name': 'Louisiana', 'county_name': 'IBERIA COUNTY', 'num_beds': 211},
#  {'state_name': 'Louisiana', 'county_name': 'IBERVILLE COUNTY', 'num_beds': 0},
#  {'state_name': 'Louisiana', 'county_name': 'JACKSON COUNTY', 'num_beds': 25},
#  {'state_name': 'Louisiana',
#   'county_name': 'JEFFERSON COUNTY',
#   'num_beds': 1628},
#  {'state_name': 'Louisiana',
#   'county_name': 'JEFFERSON DAVIS COUNTY',
#   'num_beds': 96},
#  {'state_name': 'Louisiana', 'county_name': 'LA SALLE COUNTY', 'num_beds': 84},
#  {'state_name': 'Louisiana',
#   'county_name': 'LAFAYETTE COUNTY',
#   'num_beds': 1120},
#  {'state_name': 'Louisiana',
#   'county_name': 'LAFOURCHE COUNTY',
#   'num_beds': 203},
#  {'state_name': 'Louisiana', 'county_name': 'LINCOLN COUNTY', 'num_beds': 159},
#  {'state_name': 'Louisiana',
#   'county_name': 'LIVINGSTON COUNTY',
#   'num_beds': 59},
#  {'state_name': 'Louisiana', 'county_name': 'MADISON COUNTY', 'num_beds': 25},
#  {'state_name': 'Louisiana',
#   'county_name': 'MOREHOUSE COUNTY',
#   'num_beds': 82},
#  {'state_name': 'Louisiana',
#   'county_name': 'NATCHITOCHES COUNTY',
#   'num_beds': 208},
#  {'state_name': 'Louisiana',
#   'county_name': 'ORLEANS COUNTY',
#   'num_beds': 1671},
#  {'state_name': 'Louisiana',
#   'county_name': 'OUACHITA COUNTY',
#   'num_beds': 679},
#  {'state_name': 'Louisiana',
#   'county_name': 'POINTE COUPEE COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Louisiana', 'county_name': 'RAPIDES COUNTY', 'num_beds': 966},
#  {'state_name': 'Louisiana',
#   'county_name': 'RED RIVER COUNTY',
#   'num_beds': 37},
#  {'state_name': 'Louisiana', 'county_name': 'RICHLAND COUNTY', 'num_beds': 56},
#  {'state_name': 'Louisiana', 'county_name': 'SABINE COUNTY', 'num_beds': 44},
#  {'state_name': 'Louisiana',
#   'county_name': 'SAINT BERNARD COUNTY',
#   'num_beds': 0},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. BERNARD COUNTY',
#   'num_beds': 0},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. CHARLES COUNTY',
#   'num_beds': 59},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. HELENA COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. JAMES COUNTY',
#   'num_beds': 20},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. JOHN THE BAPTIST COUNTY',
#   'num_beds': 62},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. LANDRY COUNTY',
#   'num_beds': 605},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. MARTIN COUNTY',
#   'num_beds': 25},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. MARY COUNTY',
#   'num_beds': 187},
#  {'state_name': 'Louisiana',
#   'county_name': 'ST. TAMMANY COUNTY',
#   'num_beds': 946},
#  {'state_name': 'Louisiana',
#   'county_name': 'TANGIPAHOA COUNTY',
#   'num_beds': 424},
#  {'state_name': 'Louisiana',
#   'county_name': 'TERREBONNE COUNTY',
#   'num_beds': 367},
#  {'state_name': 'Louisiana', 'county_name': 'UNION COUNTY', 'num_beds': 54},
#  {'state_name': 'Louisiana',
#   'county_name': 'VERMILION COUNTY',
#   'num_beds': 95},
#  {'state_name': 'Louisiana', 'county_name': 'VERNON COUNTY', 'num_beds': 119},
#  {'state_name': 'Louisiana',
#   'county_name': 'WASHINGTON COUNTY',
#   'num_beds': 45},
#  {'state_name': 'Louisiana', 'county_name': 'WEBSTER COUNTY', 'num_beds': 196},
#  {'state_name': 'Louisiana',
#   'county_name': 'WEST CARROLL COUNTY',
#   'num_beds': 21},
#  {'state_name': 'Louisiana',
#   'county_name': 'WEST FELICIANA COUNTY',
#   'num_beds': 22},
#  {'state_name': 'Louisiana', 'county_name': 'WINN COUNTY', 'num_beds': 99},
#  {'state_name': 'Maine',
#   'county_name': 'ANDROSCOGGIN COUNTY',
#   'num_beds': 483},
#  {'state_name': 'Maine', 'county_name': 'AROOSTOOK COUNTY', 'num_beds': 256},
#  {'state_name': 'Maine', 'county_name': 'CUMBERLAND COUNTY', 'num_beds': 1269},
#  {'state_name': 'Maine', 'county_name': 'FRANKLIN COUNTY', 'num_beds': 65},
#  {'state_name': 'Maine', 'county_name': 'HANCOCK COUNTY', 'num_beds': 114},
#  {'state_name': 'Maine', 'county_name': 'KENNEBEC COUNTY', 'num_beds': 773},
#  {'state_name': 'Maine', 'county_name': 'KNOX COUNTY', 'num_beds': 109},
#  {'state_name': 'Maine', 'county_name': 'LINCOLN COUNTY', 'num_beds': 84},
#  {'state_name': 'Maine', 'county_name': 'OXFORD COUNTY', 'num_beds': 75},
#  {'state_name': 'Maine', 'county_name': 'PENOBSCOT COUNTY', 'num_beds': 773},
#  {'state_name': 'Maine', 'county_name': 'PISCATAQUIS COUNTY', 'num_beds': 50},
#  {'state_name': 'Maine', 'county_name': 'SOMERSET COUNTY', 'num_beds': 50},
#  {'state_name': 'Maine', 'county_name': 'WALDO COUNTY', 'num_beds': 25},
#  {'state_name': 'Maine', 'county_name': 'WASHINGTON COUNTY', 'num_beds': 50},
#  {'state_name': 'Maine', 'county_name': 'YORK COUNTY', 'num_beds': 294},
#  {'state_name': 'Maryland', 'county_name': 'ALLEGANY COUNTY', 'num_beds': 451},
#  {'state_name': 'Maryland',
#   'county_name': 'ANNE ARUNDEL COUNTY',
#   'num_beds': 673},
#  {'state_name': 'Maryland',
#   'county_name': 'BALTIMORE CITY COUNTY',
#   'num_beds': 4613},
#  {'state_name': 'Maryland',
#   'county_name': 'BALTIMORE COUNTY',
#   'num_beds': 1983},
#  {'state_name': 'Maryland', 'county_name': 'CALVERT COUNTY', 'num_beds': 76},
#  {'state_name': 'Maryland', 'county_name': 'CARROLL COUNTY', 'num_beds': 409},
#  {'state_name': 'Maryland', 'county_name': 'CECIL COUNTY', 'num_beds': 122},
#  {'state_name': 'Maryland', 'county_name': 'CHARLES COUNTY', 'num_beds': 89},
#  {'state_name': 'Maryland',
#   'county_name': 'DORCHESTER COUNTY',
#   'num_beds': 409},
#  {'state_name': 'Maryland',
#   'county_name': 'FREDERICK COUNTY',
#   'num_beds': 308},
#  {'state_name': 'Maryland', 'county_name': 'GARRETT COUNTY', 'num_beds': 55},
#  {'state_name': 'Maryland', 'county_name': 'HARFORD COUNTY', 'num_beds': 255},
#  {'state_name': 'Maryland', 'county_name': 'HOWARD COUNTY', 'num_beds': 581},
#  {'state_name': 'Maryland', 'county_name': 'KENT COUNTY', 'num_beds': 26},
#  {'state_name': 'Maryland',
#   'county_name': 'MONTGOMERY COUNTY',
#   'num_beds': 1492},
#  {'state_name': 'Maryland',
#   'county_name': "PRINCE GEORGE'S COUNTY",
#   'num_beds': 866},
#  {'state_name': 'Maryland', 'county_name': 'SOMERSET COUNTY', 'num_beds': 89},
#  {'state_name': 'Maryland',
#   'county_name': "ST. MARY'S COUNTY",
#   'num_beds': 95},
#  {'state_name': 'Maryland', 'county_name': 'TALBOT COUNTY', 'num_beds': 132},
#  {'state_name': 'Maryland',
#   'county_name': 'WASHINGTON COUNTY',
#   'num_beds': 372},
#  {'state_name': 'Maryland', 'county_name': 'WICOMICO COUNTY', 'num_beds': 416},
#  {'state_name': 'Maryland', 'county_name': 'WORCESTER COUNTY', 'num_beds': 45},
#  {'state_name': 'Massachusetts',
#   'county_name': 'BARNSTABLE COUNTY',
#   'num_beds': 407},
#  ...]
