# %%
import Import_County

# %%
US = Import_County.import_county()
US
# Out:
#              Date                       _id Province/State County/City  \
# 0      2020-01-22  5e9a212429f40b22fca03640        Alabama     Autauga
# 1      2020-01-23  5e9a212429f40b22fca03641        Alabama     Autauga
# 2      2020-01-24  5e9a212429f40b22fca03642        Alabama     Autauga
# 3      2020-01-25  5e9a212429f40b22fca03643        Alabama     Autauga
# 4      2020-01-26  5e9a212429f40b22fca03644        Alabama     Autauga
# ...           ...                       ...            ...         ...
# 279323 2020-04-12  5e9a22da29f40b22fca455bf        Wyoming      Weston
# 279324 2020-04-13  5e9a22da29f40b22fca455c0        Wyoming      Weston
# 279325 2020-04-14  5e9a22da29f40b22fca455c1        Wyoming      Weston
# 279326 2020-04-15  5e9a22da29f40b22fca455c2        Wyoming      Weston
# 279327 2020-04-16  5e9a22da29f40b22fca455c3        Wyoming      Weston
#
#            Latitude     Longitude  Confirmed  Confirmed_New  Death  Death_New  \
# ...

# %%
top10 = Import_County.top10_county()
top10
# Out:
#           Date                       _id Province/State County/City  \
# 0   2020-01-22  5e9a223e29f40b22fca2a66c       New York    New York
# 1   2020-01-23  5e9a223e29f40b22fca2a66d       New York    New York
# 2   2020-01-24  5e9a223e29f40b22fca2a66e       New York    New York
# 3   2020-01-25  5e9a223e29f40b22fca2a66f       New York    New York
# 4   2020-01-26  5e9a223e29f40b22fca2a670       New York    New York
# ..         ...                       ...            ...         ...
# 855 2020-04-12  5e9a223529f40b22fca28c89     New Jersey       Essex
# 856 2020-04-13  5e9a223529f40b22fca28c8a     New Jersey       Essex
# 857 2020-04-14  5e9a223529f40b22fca28c8b     New Jersey       Essex
# 858 2020-04-15  5e9a223529f40b22fca28c8c     New Jersey       Essex
# 859 2020-04-16  5e9a223529f40b22fca28c8d     New Jersey       Essex
#
#         Latitude     Longitude  Confirmed  Confirmed_New  Death  Death_New  \
# ...

# %%
Import_County.top10_infection_plot()

# %%
Import_County.top10_cml_infection_plot()

# %%
Import_County.top10_after100_plot()

# %%
Import_County.top10_after100_cml_plot()
